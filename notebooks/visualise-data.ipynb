# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import glob
from visualize import *
plt.style.use('science')

# %%
# # We need to do a bit of formatting to get the data into a format we can use
# # Specifically, add date
# # Note that formatting has to be done for once on the processed data
# # If the graphs are plotted, then the data already has the correct format

# for indicator in ['t2m', 'tp']:
#     weighted_average = pd.read_csv(f'../data/processed/era5/{indicator}/weighted_average.csv', index_col=0)
#     average = pd.read_csv(f'../data/processed/era5/{indicator}/average.csv', index_col=0).iloc[10:,:]
#     x = pd.date_range(start='1980-01-01', end='2018-12-31', freq='MS')
#     weighted_average.columns = x
#     average.columns = x
#     weighted_average.to_csv(f'../data/processed/era5/{indicator}/weighted_average.csv')
#     average.to_csv(f'../data/processed/era5/{indicator}/average.csv')

# for indicator in ['csdi', 'wsdi']:
#     weighted_average = pd.read_csv(f'../data/processed/agroclimatic_indicators/{indicator}/weighted_average.csv', index_col=0)
#     average = pd.read_csv(f'../data/processed/agroclimatic_indicators/{indicator}/average.csv', index_col=0).iloc[10:,:]
#     x = pd.date_range(start='1980-01-01', end='2019-01-01', freq='4MS')
#     weighted_average.columns = x
#     average.columns = x
#     weighted_average.to_csv(f'../data/processed/agroclimatic_indicators/{indicator}/weighted_average.csv')
#     average.to_csv(f'../data/processed/agroclimatic_indicators/{indicator}/average.csv')
    
# for indicator in ['r10mm']:
#     weighted_average = pd.read_csv(f'../data/processed/agroclimatic_indicators/{indicator}/weighted_average.csv', index_col=0)
#     average = pd.read_csv(f'../data/processed/agroclimatic_indicators/{indicator}/average.csv', index_col=0).iloc[10:,:]
#     x = pd.read_csv(f'../data/processed/agroclimatic_indicators/{indicator}/t.csv')
#     x = pd.to_datetime(x['0'])[:-1]
#     weighted_average.columns = x
#     average.columns = x
#     weighted_average.to_csv(f'../data/processed/agroclimatic_indicators/{indicator}/weighted_average.csv')
#     average.to_csv(f'../data/processed/agroclimatic_indicators/{indicator}/average.csv')
    
# countries = ['Bangladesh',
#              'Ethiopia',
#              'Jordan',
#              'Kenya',
#              'Pakistan',
#              'Rwanda',
#              'Sudan',
#              'South Sudan',
#              'Tanzania',
#              'Uganda']

# for indicator in ['t2m', 'tp']:
#     for country in countries:
#         grid = pd.read_csv(f'../data/processed/era5/{indicator}/{country}Grid.csv', index_col=0)
#         x = pd.date_range(start='1980-01-01', end='2018-12-31', freq='MS')
#         grid.columns = x
#         grid.to_csv(f'../data/processed/era5/{indicator}/{country}Grid.csv')

# %% [markdown]
# ## 1. Temperature

# %%
# plot_single_graph('temperature', '°C')

# %%
plot_grid_w_average('temperature', 'temp', '°C')
# Out:
# Number of camps in Bangladesh: 1
# Number of camps in Ethiopia: 2
# Number of camps in Jordan: 1
# Number of camps in Kenya: 2
# Number of camps in Pakistan: 2
# Number of camps in Rwanda: 1
# Number of camps in South Sudan: 2
# Number of camps in Sudan: 2
# Number of camps in Tanzania: 2
# Number of camps in Uganda: 5

# %%
descriptive_statistics = plot_grid_w_grid('temperature', 'temp', '°C', plot_quintiles=False)
# Out:
# Number of camps in Bangladesh: 1
# Number of camps in Ethiopia: 2
# Number of camps in Jordan: 1
# Number of camps in Kenya: 2
# Number of camps in Pakistan: 2
# Number of camps in Rwanda: 1
# Number of camps in South Sudan: 2
# Number of camps in Sudan: 2
# Number of camps in Tanzania: 2
# Number of camps in Uganda: 5

# %%
df = pd.DataFrame.from_dict(descriptive_statistics, orient="index").stack().to_frame()
# to break out the lists into columns
df = pd.DataFrame(df[0].values.tolist(), index=df.index)

# %%
df.index.names = ['Country', 'Settlement']
temperature = df.copy()

# %% [markdown]
# ## 2. Precipitation

# %%
# plot_single_graph('precipitation', 'mm/day')

# %%
plot_grid_w_average('precipitation', 'precip', 'mm/day')
# Out:
# Number of camps in Bangladesh: 1
# Number of camps in Ethiopia: 2
# Number of camps in Jordan: 1
# Number of camps in Kenya: 2
# Number of camps in Pakistan: 2
# Number of camps in Rwanda: 1
# Number of camps in South Sudan: 2
# Number of camps in Sudan: 2
# Number of camps in Tanzania: 2
# Number of camps in Uganda: 5

# %%
descriptive_statistics = plot_grid_w_grid('precipitation', 'precip', 'mm/day', plot_quintiles=False)
# Out:
# Number of camps in Bangladesh: 1
# Number of camps in Ethiopia: 2
# Number of camps in Jordan: 1
# Number of camps in Kenya: 2
# Number of camps in Pakistan: 2
# Number of camps in Rwanda: 1
# Number of camps in South Sudan: 2
# Number of camps in Sudan: 2
# Number of camps in Tanzania: 2
# Number of camps in Uganda: 5

# %%
df = pd.DataFrame.from_dict(descriptive_statistics, orient="index").stack().to_frame()
# to break out the lists into columns
df = pd.DataFrame(df[0].values.tolist(), index=df.index)

# %%
df.index.names = ['Country', 'Settlement']
rainfall = df.copy()

# %% [markdown]
# ## 3. Heatwaves

# %%
# plot_single_graph('heatwaves', 'days')

# %%
plot_grid_w_average('heatwaves', 'dur', 'days')
# Out:
# Number of camps in Bangladesh: 1
# Number of camps in Ethiopia: 2
# Number of camps in Jordan: 1
# Number of camps in Kenya: 2
# Number of camps in Pakistan: 2
# Number of camps in Rwanda: 1
# Number of camps in South Sudan: 2
# Number of camps in Sudan: 2
# Number of camps in Tanzania: 2
# Number of camps in Uganda: 5

# %%
descriptive_statistics = plot_grid_w_grid('heatwaves', 'dur', 'days')
# Out:
# Number of camps in Bangladesh: 1
# Number of camps in Ethiopia: 2
# Number of camps in Jordan: 1
# Number of camps in Kenya: 2
# Number of camps in Pakistan: 2
# Number of camps in Rwanda: 1
# Number of camps in South Sudan: 2
# Number of camps in Sudan: 2
# Number of camps in Tanzania: 2
# Number of camps in Uganda: 5

# %%
df = pd.DataFrame.from_dict(descriptive_statistics, orient="index").stack().to_frame()
# to break out the lists into columns
df = pd.DataFrame(df[0].values.tolist(), index=df.index)

# %%
df.index.names = ['Country', 'Settlement']
heatwaves = df.copy()

# %% [markdown]
# ## 4. Cold waves

# %%
# plot_single_graph('coldwaves', 'days')

# %%
plot_grid_w_average('coldwaves', 'dur', 'days')
# Out:
# Number of camps in Bangladesh: 1
# Number of camps in Ethiopia: 2
# Number of camps in Jordan: 1
# Number of camps in Kenya: 2
# Number of camps in Pakistan: 2
# Number of camps in Rwanda: 1
# Number of camps in South Sudan: 2
# Number of camps in Sudan: 2
# Number of camps in Tanzania: 2
# Number of camps in Uganda: 5

# %%
descriptive_statistics = plot_grid_w_grid('coldwaves', 'dur', 'days')
# Out:
# Number of camps in Bangladesh: 1
# Number of camps in Ethiopia: 2
# Number of camps in Jordan: 1
# Number of camps in Kenya: 2
# Number of camps in Pakistan: 2
# Number of camps in Rwanda: 1
# Number of camps in South Sudan: 2
# Number of camps in Sudan: 2
# Number of camps in Tanzania: 2
# Number of camps in Uganda: 5

# %%
df = pd.DataFrame.from_dict(descriptive_statistics, orient="index").stack().to_frame()
# to break out the lists into columns
df = pd.DataFrame(df[0].values.tolist(), index=df.index)

# %%
df.index.names = ['Country', 'Settlement']
coldwaves = df.copy()

# %% [markdown]
# ## 5. Droughts

# %%
# plot_single_graph('droughts', 'index')

# %%
plot_grid('droughts', 'dur', 'index')
# Out:
# Number of camps in Bangladesh: 1
# Number of camps in Ethiopia: 2
# Number of camps in Jordan: 1
# Number of camps in Kenya: 2
# Number of camps in Pakistan: 2
# Number of camps in Rwanda: 1
# Number of camps in South Sudan: 2
# Number of camps in Sudan: 2
# Number of camps in Tanzania: 2
# Number of camps in Uganda: 5

# %% [markdown]
# ## 6. Floods

# %%
# plot_single_graph('floods', 'days')

# %%
plot_grid_w_average('floods', 'dur', 'days')

# %%
descriptive_statistics = plot_grid_w_grid('floods', 'dur', 'days')

# %%
df = pd.DataFrame.from_dict(descriptive_statistics, orient="index").stack().to_frame()
# to break out the lists into columns
df = pd.DataFrame(df[0].values.tolist(), index=df.index)

# %%
df.index.names = ['Country', 'Settlement']
extreme_rainfall = df.copy()

# %%
pd.concat([temperature, rainfall, heatwaves, coldwaves, extreme_rainfall], axis=1, keys=['Temperature', 'Rainfall', 'Heatwaves', 'Coldwaves', 'Extreme rainfall']).to_csv('../results/descriptive_statistics.csv')
